# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Graficando los datos

# %%
x, y = np.loadtxt('D_ell.txt', unpack=True)
plt.figure(figsize=(8,6))
plt.plot(x,y,color="purple")
plt.xscale('log')
plt.xlabel('$\ell$')
plt.ylabel('$\ell(\ell+1)/2\pi C_\ell\,[\mu K^2]$')
plt.savefig('plot2.png')

# %%
data = np.genfromtxt("D_ell.csv", delimiter=",", names=["x", "y"])
plt.figure(figsize=(8,6))
plt.plot(data['x'], data['y'],color="purple")
plt.xscale('log')
plt.xlabel('$\ell$')
plt.ylabel('$\ell(\ell+1)/2\pi C_\ell\,[\mu K^2]$')
plt.savefig('plot2.png')

# %%
data['x'] #son los l
# Out:
# array([2.000e+00, 3.000e+00, 4.000e+00, ..., 5.048e+03, 5.049e+03,
#        5.050e+03])

# %%
data['y'] #son los D_l
# Out:
# array([922.92109884, 874.06873018, 830.78517945, ...,   1.16513823,
#          1.16638584,   1.16759348])

# %%
len(data)
# Out:
# 5049
